# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("DATA/player_stats.csv")
df.head()
# Out:
#    PLAYER_ID    PLAYER_NAME NICKNAME_base  TEAM_ID_base  \
# 0    1630639    A.J. Lawson          A.J.    1610612761
# 1    1631260       AJ Green            AJ    1610612749
# 2    1642358     AJ Johnson            AJ    1610612764
# 3     203932   Aaron Gordon         Aaron    1610612743
# 4    1628988  Aaron Holiday         Aaron    1610612745
#
#   TEAM_ABBREVIATION_base  AGE_base  GP_base  W_base  L_base  W_PCT_base  ...  \
# 0                    TOR      24.0       26      14      12       0.538  ...
# 1                    MIL      25.0       73      44      29       0.603  ...
# 2                    WAS      20.0       29       8      21       0.276  ...
# 3                    DEN      29.0       51      33      18       0.647  ...
# 4                    HOU      28.0       62      39      23       0.629  ...
#
#    E_PACE_RANK  PACE_RANK  sp_work_PACE_RANK  PIE_RANK  FGM_RANK_adv  \
# 0          119        122                122       329           352
# ...
